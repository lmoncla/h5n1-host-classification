# %% [markdown]
# # Classify avian sequences into domestic and wild
#
# Update on June 30, 2022: I am going to make sure I am not missing any wild bird sequences and am also going to update to the newest data. So I re-downloaded all metadata for every sequence that had an HA gene from GISAID. I also updated thte H5N1 nextstrain build with up to date IRD data and will use that input file.
#
# August 18, 2020
#
# To start on this avian flu project, I would like to use the H5N1 sequences that I have already curated for the avian-flu nextstrain build. While some of the sequences on that site are derived from the Influenza Research Database (which pulls from Genbank), others come from gisaid. Gisaid has an annotation feature where avian sequences can be annotated as domestic or wild, which is really helpful. However, most sequences are not annotated. I figured out when writing the application that sequences can generally be classified by reading the associated abstract or paper. To do that, I need to match gisaid ids with genbank ids, and use those to pull abstracts. In this notebook, I will do the following:
#
# 1. I downloaded all available H5N1 sequences from gisaid. I did not stipulate whether they required any given segment or any minimum segment length. This downloaded metadata file should provide all the available metadata for all gisaid h5n1 segments.
# 2. Read in this gisaid metadata file to a dictionary containing for each accession number, all of the associated metadata.
# 3. Next, I will read in all of the fasta files for H5N1 that are currently used for the avian-flu repo. These fasta files live in `avian-flu/data/`. I have already done a bit of work to classify hosts for the avian flu build as bird, human, nonhuman mammal, and environment. I feel pretty confident that the majority of sequences that are ambiguous will be goose and duck. So, for any sequence annotated as bird whose host in the strain name is goose or duck, then I will pull out the accession number. If the accession is a gisaid accession, then I will check the metadata dictionary to determine whether a. there is a domestic/wild annotation and b. whether there is an associated genbank id.
# 4. If there is no annotation and no genbank id, then it will be really challenging to classify. If there is an annotation, then we will use that. If there is no annotation, but there is a genbank id, then I will record that genbank id and use it to look up and output an associated abstract for that sequence.

# %%
# using the Entrez feature from bio
from Bio import Entrez
from Bio import SeqIO
import re
import time, datetime
import pandas as pd

# %%
def clean_excel_file(input_excel_metadata):
    output_filename = input_excel_metadata.replace(".xls","-cleaned.tsv")
    
    df = pd.read_excel(input_excel_metadata)
    
    # replace newlines in columns 
    df = df.replace('\n','', regex=True)
    
    # write to tsv
    df.to_csv(output_filename, sep="\t", index=False)
    return(output_filename)

# %%
def read_in_metadata_file(file):
    count = 0
    metadata_dict = {}
    genes = {"PB2":{"gisaid_id":1,"genbank_id":53},
            "PB1":{"gisaid_id":2,"genbank_id":54},
            "PA":{"gisaid_id":3,"genbank_id":55},
            "HA":{"gisaid_id":4,"genbank_id":56},
            "NP":{"gisaid_id":5,"genbank_id":57},
            "NA":{"gisaid_id":6,"genbank_id":58},
            "MP":{"gisaid_id":7,"genbank_id":59},
            "NS":{"gisaid_id":8,"genbank_id":60},}
    
    with open(file, "r") as infile:
        for line in infile:
            count += 1
            if len(line.split("\t")) < 63:
                print(count)
            strain_name = line.split("\t")[11].strip()
            passage_history = line.split("\t")[14].strip()
            host = line.split("\t")[16].strip()
            vacc_status = line.split("\t")[47].strip()
            domestic_status = line.split("\t")[51].strip()

            for gene in genes: 
                gisaid_id_column = genes[gene]['gisaid_id']
                gisaid_id = line.split("\t")[gisaid_id_column].split("|")[0]
                genbank_id_column = genes[gene]['genbank_id']
                genbank_id = line.split("\t")[genbank_id_column]

                # add to dictionary 
                metadata_dict[gisaid_id] = {"genbank_id":genbank_id,"strain":strain_name,"passage":passage_history,
                                           "vaccination_status":vacc_status,"domestic_wild":domestic_status,"host":host}

        return(metadata_dict)

# %%
#metadata_file = "/Users/lmoncla/src/h5n1-host-classification/gisaid-data/gisaid-all-h5n1-2020-08-18.txt"
metadata_file = "/Users/lmoncla/src/h5n1-host-classification/gisaid-data/gisaid-all-h5n1-2022-06-30.xls"

cleaned_metadata_tsv = clean_newlines_from_excel(metadata_file)

# %%
metadata_dict = read_in_metadata_file(cleaned_metadata_tsv)
metadata_dict
# Out:
# {'PB2 Segment_Id': {'genbank_id': 'PB2 INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'PB1 Segment_Id': {'genbank_id': 'PB1 INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'PA Segment_Id': {'genbank_id': 'PA INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'HA Segment_Id': {'genbank_id': 'HA INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'NP Segment_Id': {'genbank_id': 'NP INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'NA Segment_Id': {'genbank_id': 'NA INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'MP Segment_Id': {'genbank_id': 'MP INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'NS Segment_Id': {'genbank_id': 'NS INSDC_Upload',
#   'strain': 'Isolate_Name',
#   'passage': 'Passage_History',
#   'vaccination_status': 'Is_Vaccinated',
#   'domestic_wild': 'Domestic_Status',
#   'host': 'Host'},
#  'EPI341822': {'genbank_id': 'AB677904',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341821': {'genbank_id': 'AB677905',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341820': {'genbank_id': 'AB677906',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341819': {'genbank_id': 'AB677907',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341818': {'genbank_id': 'AB677908',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341817': {'genbank_id': 'AB677909',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341816': {'genbank_id': 'AB677910',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341815': {'genbank_id': 'AB677911',
#   'strain': 'A/peregrine falcon/Kyoto/2602A009/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341814': {'genbank_id': 'AB677912',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341813': {'genbank_id': 'AB677913',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341812': {'genbank_id': 'AB677914',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341910': {'genbank_id': 'AB677915',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341811': {'genbank_id': 'AB677916',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341810': {'genbank_id': 'AB677917',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341809': {'genbank_id': 'AB677918',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI341808': {'genbank_id': 'AB677919',
#   'strain': 'A/peregrine falcon/Aichi/2302O017/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Falco peregrinus'},
#  'EPI1944482': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944483': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944481': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944485': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944478': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944484': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944480': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1944479': {'genbank_id': '',
#   'strain': 'A/goose/Italy/IZSLT-21VIR10273/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308283': {'genbank_id': 'MF112256',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308285': {'genbank_id': 'MF112355',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308288': {'genbank_id': 'MF112452',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308291': {'genbank_id': 'MF112544',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308294': {'genbank_id': 'MF112644',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308297': {'genbank_id': 'MF112744',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308300': {'genbank_id': 'MF112844',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1308303': {'genbank_id': 'MF112944',
#   'strain': 'A/goose/Nigeria/16VIR5840-3/2015',
#   'passage': 'passage details: clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161283': {'genbank_id': 'LC364286',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161284': {'genbank_id': 'LC364287',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161285': {'genbank_id': 'LC364288',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161286': {'genbank_id': 'LC364289',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161289': {'genbank_id': 'LC364290',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161290': {'genbank_id': 'LC364291',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161291': {'genbank_id': 'LC364292',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1161292': {'genbank_id': 'LC364293',
#   'strain': 'A/goose/Vietnam/HU8-1596/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158764': {'genbank_id': 'KY437764',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158765': {'genbank_id': 'KY437765',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158767': {'genbank_id': 'KY437766',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158768': {'genbank_id': 'KY437767',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158769': {'genbank_id': 'KY437768',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158770': {'genbank_id': 'KY437769',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158771': {'genbank_id': 'KY437770',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1158772': {'genbank_id': 'KY437771',
#   'strain': 'A/goose/Yangzhou/0403/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  '': {'genbank_id': '',
#   'strain': 'A/mink/China/CY1/2017',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Mink'},
#  'EPI647532': {'genbank_id': 'KT429553',
#   'strain': 'A/goose/Egypt/BSU-NLQP-DAK-2/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI647544': {'genbank_id': 'KT429565',
#   'strain': 'A/goose/Egypt/BSU-NLQP-DAK-2/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI597828': {'genbank_id': 'KP209303',
#   'strain': 'A/goose/Egypt/1439FAOS/2014',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI593747': {'genbank_id': 'KP735806',
#   'strain': 'A/goose/Shandong/k1201/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI366427': {'genbank_id': 'JF789579',
#   'strain': 'A/goose/Huazhong/QF24/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233745': {'genbank_id': 'CY048392',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233746': {'genbank_id': 'CY048393',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233747': {'genbank_id': 'CY048394',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233748': {'genbank_id': 'CY048395',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233749': {'genbank_id': 'CY048396',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233750': {'genbank_id': 'CY048397',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233751': {'genbank_id': 'CY048398',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233752': {'genbank_id': 'CY048399',
#   'strain': 'A/goose/Nigeria/08RS848-56/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233425': {'genbank_id': 'CY048072',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233426': {'genbank_id': 'CY048073',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233427': {'genbank_id': 'CY048074',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233428': {'genbank_id': 'CY048075',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233429': {'genbank_id': 'CY048076',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233430': {'genbank_id': 'CY048077',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233431': {'genbank_id': 'CY048078',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI233432': {'genbank_id': 'CY048079',
#   'strain': 'A/goose/Nigeria/08VIR4337-544/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI231131': {'genbank_id': 'GQ355820',
#   'strain': 'A/goose/Wien/1966/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI231132': {'genbank_id': 'GQ355846',
#   'strain': 'A/goose/Wien/1966/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5779': {'genbank_id': 'AF144300',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5781': {'genbank_id': 'AF144301',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5783': {'genbank_id': 'AF144302',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5797': {'genbank_id': 'AF148678, AF144305',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5785': {'genbank_id': 'AF144303',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5787': {'genbank_id': 'AF144304',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5791': {'genbank_id': 'AF144306',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5794': {'genbank_id': 'AF144307',
#   'strain': 'A/Goose/Guangdong/1/96',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5078': {'genbank_id': 'AF098584',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5106': {'genbank_id': 'AF098598',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5132': {'genbank_id': 'AF098611',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI4983': {'genbank_id': 'AF098545',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5156': {'genbank_id': 'AF098623',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5001': {'genbank_id': 'AF098554',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5037': {'genbank_id': 'AF098568',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI5061': {'genbank_id': 'AF098576',
#   'strain': 'A/Goose/Hong Kong/w355/97',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Goose'},
#  'EPI1262': {'genbank_id': 'AB239300',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1264': {'genbank_id': 'AB239301',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1266': {'genbank_id': 'AB239302',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1250': {'genbank_id': 'AB233319',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1268': {'genbank_id': 'AB239303',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1270': {'genbank_id': 'AB239304',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1272': {'genbank_id': 'AB239305',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1275': {'genbank_id': 'AB239306',
#   'strain': 'A/bar-headed goose/Mongolia/1/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Anser indicus'},
#  'EPI1963381': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963382': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963380': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963384': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963377': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963383': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963379': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI1963378': {'genbank_id': '',
#   'strain': 'A/guineafowl/Scotland/054471/2021',
#   'passage': 'Egg Passage 1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Numida meleagris'},
#  'EPI4801': {'genbank_id': 'AF082043',
#   'strain': 'A/gull/Pennsylvania/4175/83',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Gull'},
#  'EPI98018': {'genbank_id': 'DQ107466',
#   'strain': 'A/gull/Pennsylvania/4175/83',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Gull'},
#  'EPI233913': {'genbank_id': 'CY048560',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233914': {'genbank_id': 'CY048561',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233915': {'genbank_id': 'CY048562',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233916': {'genbank_id': 'CY048563',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233917': {'genbank_id': 'CY048564',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233918': {'genbank_id': 'CY048565',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233919': {'genbank_id': 'CY048566',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI233920': {'genbank_id': 'CY048567',
#   'strain': 'A/ostrich/Nigeria/08RS848-84/2007',
#   'passage': 'E1',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Ostrich'},
#  'EPI600474': {'genbank_id': 'KP288313',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600475': {'genbank_id': 'KP288314',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI598311': {'genbank_id': 'KP288315',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600476': {'genbank_id': 'KP288316',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600477': {'genbank_id': 'KP288317',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600478': {'genbank_id': 'KP288318',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600479': {'genbank_id': 'KP288319',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI600480': {'genbank_id': 'KP288320',
#   'strain': 'A/quail/Nanchang/6631/2013',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Coturnix'},
#  'EPI1963317': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963318': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963316': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963320': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963313': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963319': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963315': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1963314': {'genbank_id': '',
#   'strain': 'A/pheasant/Wales/385129/2021',
#   'passage': 'Clinical Material',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Pheasant'},
#  'EPI1918762': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918763': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918764': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918765': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918766': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918767': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918768': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI1918769': {'genbank_id': '',
#   'strain': 'A/common pheasant /Sweden/SVA210923SZ0341/KN000366/M-2021',
#   'passage': 'Original, direct sequencing from the clinical sample',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Phasanius colchicus'},
#  'EPI289700': {'genbank_id': 'HM006747',
#   'strain': 'A/whooper swan/Mongolia/9/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI289699': {'genbank_id': 'HM006745',
#   'strain': 'A/whooper swan/Mongolia/7/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI289698': {'genbank_id': 'HM006742',
#   'strain': 'A/whooper swan/Mongolia/5/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI289697': {'genbank_id': 'HM006741',
#   'strain': 'A/whooper swan/Mongolia/4/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI234502': {'genbank_id': 'EU124213',
#   'strain': 'A/Swan/Indonesia/Malang1631-61/2007',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231254': {'genbank_id': 'GQ355838',
#   'strain': 'A/swan/Ybbs/1106/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231255': {'genbank_id': 'GQ355862',
#   'strain': 'A/swan/Ybbs/1106/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231252': {'genbank_id': 'GQ355837',
#   'strain': 'A/swan/Wien/2323/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231253': {'genbank_id': 'GQ355861',
#   'strain': 'A/swan/Wien/2323/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231250': {'genbank_id': 'GQ355836',
#   'strain': 'A/swan/Wien/1410/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231251': {'genbank_id': 'GQ355860',
#   'strain': 'A/swan/Wien/1410/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231248': {'genbank_id': 'GQ355835',
#   'strain': 'A/swan/Voecklabruck/1484/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231249': {'genbank_id': 'GQ355859',
#   'strain': 'A/swan/Voecklabruck/1484/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231246': {'genbank_id': 'GQ355834',
#   'strain': 'A/swan/Schwechat/2538/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231247': {'genbank_id': 'GQ355858',
#   'strain': 'A/swan/Schwechat/2538/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231244': {'genbank_id': 'GQ355833',
#   'strain': 'A/swan/Schaerding/1806/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231245': {'genbank_id': 'GQ355857',
#   'strain': 'A/swan/Schaerding/1806/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231242': {'genbank_id': 'GQ355832',
#   'strain': 'A/swan/Schaerding/1499/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231243': {'genbank_id': 'GQ355856',
#   'strain': 'A/swan/Schaerding/1499/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231240': {'genbank_id': 'GQ355831',
#   'strain': 'A/swan/Perg/1358/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231241': {'genbank_id': 'GQ355855',
#   'strain': 'A/swan/Perg/1358/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231237': {'genbank_id': 'GQ355830',
#   'strain': 'A/swan/Mellach/215/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231238': {'genbank_id': 'GQ355854',
#   'strain': 'A/swan/Mellach/215/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231235': {'genbank_id': 'GQ355829',
#   'strain': 'A/swan/Laakirchen/2703/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231236': {'genbank_id': 'GQ355853',
#   'strain': 'A/swan/Laakirchen/2703/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231233': {'genbank_id': 'GQ355828',
#   'strain': 'A/swan/Krems/2675/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231234': {'genbank_id': 'GQ355852',
#   'strain': 'A/swan/Krems/2675/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231231': {'genbank_id': 'GQ355827',
#   'strain': 'A/swan/Krems/2547/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231232': {'genbank_id': 'GQ355851',
#   'strain': 'A/swan/Krems/2547/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231229': {'genbank_id': 'GQ355826',
#   'strain': 'A/swan/Krems/2354/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231230': {'genbank_id': 'GQ355850',
#   'strain': 'A/swan/Krems/2354/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231227': {'genbank_id': 'GQ355825',
#   'strain': 'A/swan/Hoeflein/2048/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231228': {'genbank_id': 'GQ355849',
#   'strain': 'A/swan/Hoeflein/2048/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231225': {'genbank_id': 'GQ355824',
#   'strain': 'A/swan/Hainburg/2172/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231226': {'genbank_id': 'GQ355848',
#   'strain': 'A/swan/Hainburg/2172/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231223': {'genbank_id': 'GQ355823',
#   'strain': 'A/swan/Gmunden/2126/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231224': {'genbank_id': 'GQ355847',
#   'strain': 'A/swan/Gmunden/2126/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI231222': {'genbank_id': 'GQ355822',
#   'strain': 'A/swan/ArcheNoah/403/2006',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Swan'},
#  'EPI401466': {'genbank_id': 'AB684169',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401483': {'genbank_id': 'AB684170',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401484': {'genbank_id': 'AB684171',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401562': {'genbank_id': 'AB684254',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401485': {'genbank_id': 'AB684172',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401486': {'genbank_id': 'AB684173',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401487': {'genbank_id': 'AB684174',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI401488': {'genbank_id': 'AB684175',
#   'strain': 'A/black swan/Yamaguchi/1/2011',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus atratus'},
#  'EPI341807': {'genbank_id': 'AB677920',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341806': {'genbank_id': 'AB677921',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341805': {'genbank_id': 'AB677922',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341909': {'genbank_id': 'AB677923',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341804': {'genbank_id': 'AB677924',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341803': {'genbank_id': 'AB677925',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341802': {'genbank_id': 'AB677926',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI341801': {'genbank_id': 'AB677927',
#   'strain': 'A/tundra swan/Tottori/12-002/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus columbianus'},
#  'EPI289694': {'genbank_id': 'HM006739',
#   'strain': 'A/whooper swan/Mongolia/1/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI289696': {'genbank_id': 'HM006738',
#   'strain': 'A/whooper swan/Mongolia/1/2009',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1784': {'genbank_id': 'AB264769',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1786': {'genbank_id': 'AB264770',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1778': {'genbank_id': 'AB263751',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1780': {'genbank_id': 'AB263752',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1782': {'genbank_id': 'AB263753',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1789': {'genbank_id': 'AB265202',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1791': {'genbank_id': 'AB265203',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1794': {'genbank_id': 'AB265204',
#   'strain': 'A/whooper swan/Mongolia/2/06',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1310': {'genbank_id': 'AB239321',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1312': {'genbank_id': 'AB239322',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1314': {'genbank_id': 'AB239323',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1256': {'genbank_id': 'AB233322',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1316': {'genbank_id': 'AB239324',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1318': {'genbank_id': 'AB239325',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1320': {'genbank_id': 'AB239326',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1323': {'genbank_id': 'AB239327',
#   'strain': 'A/whooper swan/Mongolia/6/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1294': {'genbank_id': 'AB239314',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1296': {'genbank_id': 'AB239315',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1298': {'genbank_id': 'AB239316',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1254': {'genbank_id': 'AB233321',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1300': {'genbank_id': 'AB239317',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1302': {'genbank_id': 'AB239318',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1304': {'genbank_id': 'AB239319',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1307': {'genbank_id': 'AB239320',
#   'strain': 'A/whooper swan/Mongolia/4/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1278': {'genbank_id': 'AB239307',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1280': {'genbank_id': 'AB239308',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1282': {'genbank_id': 'AB239309',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1252': {'genbank_id': 'AB233320',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1284': {'genbank_id': 'AB239310',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1286': {'genbank_id': 'AB239311',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1288': {'genbank_id': 'AB239312',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1291': {'genbank_id': 'AB239313',
#   'strain': 'A/whooper swan/Mongolia/3/05',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus cygnus'},
#  'EPI1950865': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/146/2021',
#   'passage': 'original (brain tissue)',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1942302': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/104/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1942303': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/104/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941527': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941528': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941529': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941530': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941531': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941532': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941533': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI1941534': {'genbank_id': '',
#   'strain': 'A/mute swan/Croatia/101/2021',
#   'passage': 'brain tissue',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Cygnus olor'},
#  'EPI401373': {'genbank_id': 'AB684088',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401380': {'genbank_id': 'AB684089',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401381': {'genbank_id': 'AB684090',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401514': {'genbank_id': 'AB684241',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401382': {'genbank_id': 'AB684091',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401385': {'genbank_id': 'AB684092',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401383': {'genbank_id': 'AB684093',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI401384': {'genbank_id': 'AB684094',
#   'strain': 'A/mute swan/Toyama/1/2010',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Cygnus olor'},
#  'EPI1944498': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944499': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944497': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944501': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944494': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944500': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944496': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944495': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR8817-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944490': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR9210-1/2021',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Turkey'},
#  'EPI1944491': {'genbank_id': '',
#   'strain': 'A/turkey/Italy/21VIR9210-1/2021',
#   'passage': '',
#   'vaccination_status': '',
# ...
#   'strain': 'A/Hanoi/30408/2005',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI1260': {'genbank_id': 'AB239126',
#   'strain': 'A/Hanoi/30408/2005',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20628': {'genbank_id': 'AY576381, AB212051, AB212050',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20652': {'genbank_id': 'AY576393, AB212052',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20676': {'genbank_id': 'AY576405, AB212053',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20508': {'genbank_id': 'AY575870, AB212054',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20580': {'genbank_id': 'AY575906, AB212055',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20532': {'genbank_id': 'AY575882, AB212056',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20556': {'genbank_id': 'AY575894, AB212057',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI20604': {'genbank_id': 'AY576369, AB212059, AB212058',
#   'strain': 'A/Hong Kong/213/03',
#   'passage': '',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Human'},
#  'EPI2058314': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058315': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058316': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058317': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058318': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058319': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058320': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2058321': {'genbank_id': '',
#   'strain': 'A/duck/Bangladesh/18D1837/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2050826': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050827': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050829': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050822': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050828': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050823': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050824': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050825': {'genbank_id': '',
#   'strain': 'A/Barnacle goose/Luxembourg/22033922/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050818': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050819': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050821': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050814': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050820': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050815': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050816': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050817': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/22012198/2022',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050804': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050806': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050811': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050799': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050809': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050800': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050801': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050802': {'genbank_id': '',
#   'strain': 'A/Great cormorant/Luxembourg/21243185/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050791': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050794': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050797': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050784': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050796': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050786': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050787': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050789': {'genbank_id': '',
#   'strain': 'A/Grey heron/Luxembourg/21243177/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050780': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050781': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050783': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050776': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050782': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050777': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050778': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050779': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21239614/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050772': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050773': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050775': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050768': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050774': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050769': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050770': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050771': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21237199/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050764': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050765': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050767': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050760': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050766': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050761': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050762': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050763': {'genbank_id': '',
#   'strain': 'A/Canada goose/Luxembourg/21217776/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050756': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050757': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050759': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050752': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050758': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050753': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050754': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050755': {'genbank_id': '',
#   'strain': 'A/Greylag goose/Luxembourg/21217773/2021',
#   'passage': 'Original',
#   'vaccination_status': '',
#   'domestic_wild': 'Wild',
#   'host': 'Avian'},
#  'EPI2050402': {'genbank_id': '',
#   'strain': 'A/chicken/Wyoming/22-009599-001-original/2022',
#   'passage': 'original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2050403': {'genbank_id': '',
#   'strain': 'A/chicken/Wyoming/22-009599-001-original/2022',
#   'passage': 'original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2050401': {'genbank_id': '',
#   'strain': 'A/chicken/Wyoming/22-009599-001-original/2022',
#   'passage': 'original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  'EPI2050405': {'genbank_id': '',
#   'strain': 'A/chicken/Wyoming/22-009599-001-original/2022',
#   'passage': 'original',
#   'vaccination_status': '',
#   'domestic_wild': '',
#   'host': 'Avian'},
#  ...}

# %% [markdown]
# I think that I need the following functions, in this order:
# 1. read in fasta file or metadata file, and classify host species in the strain name by wild or domestic if possible.
# 2. I am going to need a species synonyms file to classify groups that are essentially the same
# 2. if duck or goose, then check to see whether that id is in the metadata dictionary and if it has a genbank id and domestic wild status
# 3. if that sequence has a domestic/wild status annotation, record that and move on
# 4. if it does not have an annotation but does have a genbank id, then use that id to look up the corresponding manuscript and return the abstract. Record the pubmed id in the dictionary.
# 5. we will require for this project to have either an unambiguous species name, an annotation, or a pubmed id that can be used to determine whether the sequence is domestic or wild.
# 6. This information will all then end up getting added into the metadata file as extra columns
# 7. For the how annotation was assigned column, I am imagining that this will be something like, "was in list of known wild bird species", "abstract curation", or "annotated in gisaid"
#
# sample dictionary:
# strain name :{accession: accession, genbank_id: genbank_id, domestic_wild_annotation: domestic_wild_annotation,
# PMID: pubmed_id, how_annotation_assigned: method}

# %%
"""I have an avian species synonyms document which both corrects spelling errors and standardizes avian host
annotations so that they all match. This document also contains assignments for these species as to whether they
are domestic or wild. Some species like duck and goose are not specific enough, but others like heron are. This
function will read in that file and output a dictionary with the original species name, the corrected name, and the 
domestic/wild classification"""

def read_in_avian_species_synonyms(synonyms_doc):
    fixes_dict = {}
    with open(synonyms_doc, "r") as infile: 
        for line in infile: 
            if not line.startswith("#"):
                if len(line.split("\t")) == 3:
                    species = line.split("\t")[0]
                    fix = line.split("\t")[1]
                    domestic_wild = line.split("\t")[2].strip()

                    fixes_dict[species] = {"fix":fix, "domestic_wild":domestic_wild}
                else:
                    species = line.split("\t")[0].strip()
                    fixes_dict[species] = {"fix":"", "domestic_wild":""}
    return(fixes_dict)

# %%
"""some strains have weird passage histories or should otherwise be excluded. This is a list to hold those"""

def read_in_exclude_file(exclude_file):
    exclude_dict = {}
    
    with open(exclude_file, "r") as infile: 
        for line in infile: 
            if "#" not in line and line != "\n":
                strain_name = line.split("\t")[0]
                accession = line.split("\t")[1]
                exclude_dict[strain_name] = accession
                
    return(exclude_dict)

# %%
"""some strains are improperly formatted and need to have a host annotation added explicitly"""

def read_in_strain_host_fixes(strain_host_fixes_file):
    
    strain_host_fixes_dict = {}
    
    with open(strain_host_fixes_file, "r") as infile: 
        for line in infile: 
            if "#" not in line:
                strain_name = line.split("\t")[0]
                host_annotation = line.split("\t")[1]
                corrected_strain = line.split("\t")[2]
                strain_host_fixes_dict[strain_name] = {"host_species":host_annotation,"corrected_strain":corrected_strain}
                
    return(strain_host_fixes_dict)

# %%
"""given the species fixes in the annotations file, standardize the species annotation"""

def standardize_host_species(strain_name, host_group, fixes_dict):
    
    # standardize host species names using fix file and and categorize domestic/wild by species if possible
    if host_group.lower() == "avian": 
        host_species = strain_name.split("/")[1].lower()
            
        if host_species in fixes_dict:
            species_fix = fixes_dict[host_species]['fix']
            
        else:
            print("not in dictionary: ",host_species, strain_name)
            species_fix = host_species
                
    else:
        host_species = host_group
        species_fix = host_group

    return(host_species, species_fix)

# %%
"""given a host species, determine whether that species has a clear domestic/wild classification"""

def check_for_annotation_by_species(host_species,fixes_dict):
    
    if host_species in fixes_dict:
        domestic_wild_status = fixes_dict[host_species]['domestic_wild']
    
    else:
        domestic_wild_status = ""
    
    return(domestic_wild_status)

# %%
"""given an accession, check to see whether it is from gisaid and if so, whether it has a domestic wild annotation"""

def check_for_annotation_by_gisaid(accession,metadata_dict):
    
    if accession.startswith("EPI") and len(accession) == 10 and accession in metadata_dict:
        domestic_wild_status = metadata_dict[accession]['domestic_wild'].lower()
    else:
        domestic_wild_status = ""
        
    return(domestic_wild_status)

# %%
def return_status_and_annotation_method(domestic_wild_status_by_species,domestic_wild_status_by_gisaid):
    
    # first check to make sure that the different methods did not return conflicting annotations
    if domestic_wild_status_by_species != "" and domestic_wild_status_by_gisaid != "" and domestic_wild_status_by_species != domestic_wild_status_by_gisaid:
        print("conflicting annotations ",domestic_wild_status_by_species,domestic_wild_status_by_gisaid)
    
    # if the species is informative and gisaid had an annotation
    elif domestic_wild_status_by_species != "" and domestic_wild_status_by_gisaid != "" and domestic_wild_status_by_species == domestic_wild_status_by_gisaid:
        domestic_wild = domestic_wild_status_by_species
        annotation_method = "species name and gisaid"
    
    # if only the species could be used the classify
    elif domestic_wild_status_by_species != "" and domestic_wild_status_by_gisaid == "":
        annotation_method = "species name"
        domestic_wild = domestic_wild_status_by_species
    
    # if only gisaid could be used to classify
    elif domestic_wild_status_by_species == "" and domestic_wild_status_by_gisaid != "":
        annotation_method = "gisaid annotation"
        domestic_wild = domestic_wild_status_by_gisaid
        
    # if neither could be used to classify
    elif domestic_wild_status_by_species == "" and domestic_wild_status_by_gisaid == "":
        domestic_wild = ""
        annotation_method = ""
    
    # if there is somehow another option I'm not thinking of
    else:
        print("something weird is happening!", domestic_wild_status_by_species,domestic_wild_status_by_gisaid)
        
    return(domestic_wild, annotation_method)

# %%
"""given an accession number, determine if it is from gisaid or genbank. If from gisaid, look up the corresponding
genbank id for it if available. If not, return a blank string"""

def return_genbank_accession(accession,metadata_dict):
    
    accession_stripped = accession.replace("_","").replace("-","")
 
    # if the accession is a gisaid accession
    if accession_stripped.startswith("EPI"):
        if accession_stripped in metadata_dict:
            genbank_id = metadata_dict[accession_stripped]['genbank_id']
        else: 
            genbank_id = ""
            
    elif len(accession_stripped) == 8: 
        genbank_id = accession   #for a genbank lookup, we need to retain the _ and -, but for gisaid, we do not
    
    else:
        print("this does not follow the rules ", accession)
        
    return(genbank_id)

# %%
"""given an accession number, pull the genbank entry that it corresponds to"""

def fetch_genbank_entry(accession_number):
    
    if accession_number != "":
        Entrez.email = "lhmoncla@gmail.com"      # need to enter an email

        # fetch from the nucleotide database, return a genbank object in text format, with id = genbank accession
        handle = Entrez.efetch(db="nucleotide", rettype="gb", retmode="text", id=accession_number)
        genbank_result = handle.read()
        
    else: 
        genbank_result = ""
        
    return(genbank_result)

# %%
"""given a genbank result, pull the pubmed id from it"""

def return_PMID(genbank_result):
    if genbank_result != "":
        SearchStr = 'PUBMED\\ \\ \\ [0-9]{8}'
        result = re.search(SearchStr,genbank_result)

        if result:
            PMID = result.group(0).split("   ")[1]
        else:
            PMID = ""
            
    else:
        PMID = ""
    
    return(PMID)

# %%
def query_genbank(genbank_id):
    from urllib.error import HTTPError

    flag = True
    
    while flag:
        try:
            time.sleep(0.35) # Sleep; genbank will throw an error if you are hitting it with more than 3 hits per second
            genbank_entry = fetch_genbank_entry(genbank_id)
            pubmed_id = return_PMID(genbank_entry)
            flag = False
        except HTTPError as e:
            time.sleep(1)
            print(e)
    
    return(pubmed_id)

# %%
def fix_host_species_and_classify(metadata_file, metadata_dict,fixes_dict,exclude_dict,strain_host_fixes_dict,output_file,master_dict):
    
    with open(output_file, "w") as outfile:
        line_to_write = "\t".join(["strain","virus","isolate_id","date","region","country","division","location","host","originating_lab","submitting_lab","host_species","host_species_standardized","domestic_wild","annotation_method","genbank_id","pubmed_id"])
        outfile.write(line_to_write + "\n")
    output_dict = {}
    
    with open(metadata_file, "r") as infile: 
        for line in infile:
            if "originating_lab" not in line:
                strain_name = line.split("\t")[0]
                host_group =  line.split("\t")[8].lower()
                accession = line.split("\t")[2]

                """filter out strains that should be excluded"""
                if strain_name not in exclude_dict:
                    
                    """first, see if we have already classified this strain"""
                    if strain_name in master_dict: 
                        host_species = master_dict[strain_name]['host_species']
                        host_species_standardized = master_dict[strain_name]['standardized_host_species']
                        domestic_wild = master_dict[strain_name]['domestic_wild']
                        annotation_method = master_dict[strain_name]['annotation_method']
                        host_group = master_dict[strain_name]['host_group']
                        pubmed_id = master_dict[strain_name]['pubmed_id']
                        
                        # for these, we still need to look up a new genbank id
                        genbank_id = return_genbank_accession(accession,metadata_dict)
                        
                    else:                 
                        """if the strain is in the strain host fixes doc, add in the host species here; 
                        else, standardize the host species name with the species synonyms"""
                        if strain_name in strain_host_fixes_dict:
                            host_species = strain_host_fixes_dict[strain_name]['host_species']
                            host_species_standardized = strain_host_fixes_dict[strain_name]['host_species']

                        else:
                            host_species,host_species_standardized = standardize_host_species(strain_name, host_group, fixes_dict)


                        """now, if the host group is avian, check for domestic wild status by its species name and by gisaid
                        annotation"""
                        if host_group == "avian":
                            domestic_wild_status_by_species = check_for_annotation_by_species(host_species,fixes_dict)
                            domestic_wild_status_by_gisaid = check_for_annotation_by_gisaid(accession,metadata_dict)
                            domestic_wild,annotation_method = return_status_and_annotation_method(domestic_wild_status_by_species,domestic_wild_status_by_gisaid)                

                        else:
                            domestic_wild = host_group
                            annotation_method = ""

                        """now, return the genbank ids"""
                        genbank_id = return_genbank_accession(accession,metadata_dict)


                        """pull the genbank entry and pubmed id for the associated paper"""
                        pubmed_id = query_genbank(genbank_id)

                    
                    
                    """now write out a dictionary"""
                    output_dict[strain_name] = {"host_species":host_species,"standardized_host_species":host_species_standardized,
                                               "domestic_wild":domestic_wild,"annotation_method":annotation_method,
                                                "genbank_id":genbank_id, "host_group":host_group,"pubmed_id":pubmed_id}

                    line_to_write = "\t".join([host_species,host_species_standardized,domestic_wild,annotation_method,genbank_id,pubmed_id])
                    with open(output_file, "a") as outfile: 
                        outfile.write(line.strip() + "\t" + line_to_write + "\n")
            
    return(output_dict)

# %%
avian_synonyms_file = "/Users/lmoncla/src/h5n1-host-classification/all-avian-species.txt"
strain_host_fixes = "/Users/lmoncla/src/h5n1-host-classification/strain-host-fixes.tsv"
exclude_file = "/Users/lmoncla/src/h5n1-host-classification/exclude.txt"

todays_date = (datetime.datetime.now()).strftime('%Y-%m-%d')
output_file_directory = "/Users/lmoncla/src/h5n1-host-classification/metadata-with-annotations/"

avian_fixes_dict = read_in_avian_species_synonyms(avian_synonyms_file)
to_exclude_dict = read_in_exclude_file(exclude_file)
strain_host_fixes_dict = read_in_strain_host_fixes(strain_host_fixes)

# %%
# run for all genes to make sure I have all the hosts I need
fasta_directory = "/Users/lmoncla/src/avian-flu/data/"
metadata_directory = "/Users/lmoncla/src/avian-flu/results/"
genes_to_run = ['ha']#['pb2','pb1','pa','ha','np','na','mp','ns']
all_genes_dict = {}

for gene in genes_to_run:
    fasta_file = fasta_directory + "h5n1_"+gene+".fasta"
    metadata_file = metadata_directory + "metadata_h5n1_" + gene + ".tsv"
    output_file = output_file_directory + "metadata_h5n1_"+gene+"_with_accessions_"+todays_date+".txt"
    gene_dict = fix_host_species_and_classify(metadata_file, metadata_dict,avian_fixes_dict,to_exclude_dict,strain_host_fixes_dict,output_file,all_genes_dict)
    
    # update the dictionary with new entries. This will retain the old keys and values, but add in new ones
    all_genes_dict.update(gene_dict)
# Out:
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-66-fded754337d3> in <module>
#       9     metadata_file = metadata_directory + "metadata_h5n1_" + gene + ".tsv"
#      10     output_file = output_file_directory + "metadata_h5n1_"+gene+"_with_accessions_"+todays_date+".txt"
# ---> 11     gene_dict = fix_host_species_and_classify(metadata_file, metadata_dict,avian_fixes_dict,to_exclude_dict,strain_host_fixes_dict,output_file,all_genes_dict)
#      12
#      13     # update the dictionary with new entries. This will retain the old keys and values, but add in new ones
#
# <ipython-input-64-f01deae480af> in fix_host_species_and_classify(metadata_file, metadata_dict, fixes_dict, exclude_dict, strain_host_fixes_dict, output_file, master_dict)
#      55
#      56                         """pull the genbank entry and pubmed id for the associated paper"""
# ---> 57                         pubmed_id = query_genbank(genbank_id)
#      58
#      59
#
# <ipython-input-41-22a2235f9e52> in query_genbank(genbank_id)
#       7         try:
#       8             time.sleep(0.35) # Sleep; genbank will throw an error if you are hitting it with more than 3 hits per second
# ----> 9             genbank_entry = fetch_genbank_entry(genbank_id)
#      10             pubmed_id = return_PMID(genbank_entry)
#      11             flag = False
#
# <ipython-input-39-9bbd81b15aaf> in fetch_genbank_entry(accession_number)
#       7
#       8         # fetch from the nucleotide database, return a genbank object in text format, with id = genbank accession
# ----> 9         handle = Entrez.efetch(db="nucleotide", rettype="gb", retmode="text", id=accession_number)
#      10         genbank_result = handle.read()
#      11
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/site-packages/Bio/Entrez/__init__.py in efetch(db, **keywords)
#     182             # more than about 200 IDs
#     183             post = True
# --> 184     return _open(cgi, variables, post=post)
#     185
#     186
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/site-packages/Bio/Entrez/__init__.py in _open(cgi, params, post, ecitmatch)
#     541             handle = _urlopen(cgi, data=_as_bytes(options))
#     542         else:
# --> 543             handle = _urlopen(cgi)
#     544     except _HTTPError as exception:
#     545         raise exception
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda/envs/LHM-basics/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
# so, there are 9206 unique strains in our possession
len(all_genes_dict)

# %% [markdown]
# ## Pull abstracts to read
#
# Given this new metadata file, for all bird sequences that don't have an annotation yet and do have a pubmed id, pull the abstract so that I can read it to classify.

# %%
def collate_unique_PMIDs(metadata_file, PMIDs, cannot_classify, classify_by_abstract):
    
    with open(metadata_file, "r") as infile: 
        for line in infile: 
            if "originating_lab" not in line:
                strain = line.split("\t")[0]
                host_group = line.split("\t")[8].lower()
                domestic_wild = line.split("\t")[13]
                PMID = line.split("\t")[16].strip()
                
                if host_group == "avian" and domestic_wild == "" and PMID != "":
                    PMIDs.append(PMID)
                    classify_by_abstract.append(strain)
                elif host_group == "avian" and domestic_wild == "" and PMID == "":
                    cannot_classify.append(strain)
    
    PMIDs = list(set(PMIDs))
    cannot_classify = list(set(cannot_classify))
    classify_by_abstract = list(set(classify_by_abstract))
    return(PMIDs, cannot_classify, classify_by_abstract)

# %%
def pull_abstract(PMID):
    
    pmid_handle = Entrez.efetch(db='pubmed', id=PMID, retmode='text', rettype='abstract')
    abstract = pmid_handle.read()
    
    return(abstract)

# %%
def return_necessary_abstracts(PMIDs, abstracts_output_filename):
    
    with open(abstracts_output_filename, "w") as outfile: 
        outfile.write("")
    
    for p in PMIDs: 
        abstract = pull_abstract(p)
                    
        with open(abstracts_output_filename, "a") as outfile: 
            outfile.write(p + "\n")
            outfile.write(abstract + "\n")

# %%
metadata_directory = "/Users/lmoncla/src/h5n1-host-classification/metadata-with-annotations/"
abstracts_output_filename = "/Users/lmoncla/src/h5n1-host-classification/abstracts/abstracts-"+todays_date+".txt"

genes_to_run = ['pb2','pb1','pa','ha','np','na','mp','ns']
unique_PMIDs = []
cannot_classify = []
classify_by_abstract = []

for gene in genes_to_run: 
    metadata_input_file = metadata_directory + "metadata_h5n1_" + gene + "_with_accessions_2020-09-28.txt"
    unique_PMIDs,cannot_classify,classify_by_abstract = collate_unique_PMIDs(metadata_input_file, unique_PMIDs, cannot_classify, classify_by_abstract)

# print the number of abstracts I need to read, and the number of strains that can't be classified at all, and the 
# number of strains that will be captured by abstract classification
print(len(unique_PMIDs), len(cannot_classify), len(classify_by_abstract))
# Out:
# 146 1824 1292

# %%
return_necessary_abstracts(unique_PMIDs, abstracts_output_filename)

# %% [markdown]
# # Read in annotations from abstract reading
#
# I read ~150 abstracts to manually classify avian sequences from bird species that can be ambiguous. This was primarily for ducks, geese, turkeys, pigeons, and generic fowl. There were some papers that did not specify where the samples came from, but most did. The vast majority were part of poultry surveillance or outbreak investigation, but there were also a surprising number of wild bird sequences. I ended up doing this in 2 ways:
#
# 1. classifying all sequences for a given paper: for most of the papers, they describe either only domestic or wild, or all of the wild sequences have host species designations that are clearly wild (like "stork"). For these situations, we can just then label all leftover ambiguous sequences from that paper with a single annotation. This is true for the vast majority of abstracts.
#
# 2. classify each strain individually: there were some papers for which they looked at both domestic and wild birds, and the strain names they supply are not really sufficient for classifying (for example, domestic and wild ducks are just labelled "duck"). Luckily, for a few of these papers, they do provide explicit lists in their methods or supplemental materials sections where they specify which strains came from domestic or wild birds. For these situations, I have another text file where I have the strain name, the pubmed id, and the annotation for that specific strain.
#
# So I will now process these remaining samples as follows:
# 1. read in the current metadata with annotations files. For all avian sequences for which `domestic_wild` is currently unknown, and for which `PMID` is not blank, do the following:
# 2. first, read in the annotations file specifying a single designation per paper. If the pubmed id was informative, this file will have an annotation of either "domestic" or "wild". If I could not figure it out, the annotation is blank. If while reading the paper I figured out that I needed to annotate each strain separately, this file has an annotation that says "see strain list".
# 3. If the annotation is "see strain list", then look up this strain name in the strain names annotation list.
# 4. If at the end of all this there still is not an annotation, then we will not be able to annotate it.

# %%
def read_in_classified_abstracts(abstracts_classified_file):
    output_dict = {}
    
    with open(abstracts_classified_file, "r") as infile:
        for line in infile:
            if line != "\n":
                PMID = line.split("\t")[0]
                domestic_wild = line.split("\t")[1]
                notes = line.split("\t")[2]

                output_dict[PMID] = domestic_wild
    return(output_dict)

# %%
def read_in_strain_specific_classifications_file(strain_classification_file):
    
    output_dict = {}
    with open(strain_classification_file, "r") as infile: 
        for line in infile:
            if line != "\n":
                strain_name = line.split("\t")[0]                
                domestic_wild = line.split("\t")[1]
                PMID = line.split("\t")[2].strip()
                
                if PMID not in output_dict: 
                    output_dict[PMID] = {}
                
                output_dict[PMID][strain_name] = domestic_wild
    return(output_dict)

# %%
def add_manual_annotations(metadata_file, abstracts_dict, strain_abstract_dict, output_filename):
    
    with open(output_filename, "w") as outfile: 
        outfile.write("")
    
    with open(metadata_file, "r") as infile: 
        for line in infile: 
            if "originating_lab" not in line:
                strain = line.split("\t")[0]
                host_group = line.split("\t")[8].lower()
                current_domestic_wild = line.split("\t")[13]
                current_annotation_method = line.split("\t")[14]
                PMID = line.split("\t")[16].strip()
                
                """add in annotations that I manually curated"""
                if host_group == "avian" and current_domestic_wild == "" and PMID != "":
                    if PMID in abstracts_dict and abstracts_dict[PMID] != "":
                        domestic_wild = abstracts_dict[PMID]
                        annotation_method = "manual curation"
                        
                        
                        """if I needed to annotate each strain separately, look that up in the strains file"""
                        if domestic_wild == "see strain list":
                            if PMID in strain_abstract_dict and strain in strain_abstract_dict[PMID]:
                                domestic_wild = strain_abstract_dict[PMID][strain]
                                annotation_method = "manual curation"
                            else:
                                domestic_wild = ""
                    
                    else:
                        domestic_wild = ""
                        annotation_method = ""
                    
                    first_part = "\t".join(line.split("\t")[0:13])
                    last_part = "\t".join(line.split("\t")[15:])
                    line_to_write = "\t".join([first_part,domestic_wild, annotation_method,last_part])
                
                
                # if it already has an annotation, or if it doesn't but there isn't an abstract, move on
                else:
                    line_to_write = line
                
            else:
                line_to_write = line
            
            """write it out"""
            with open(output_filename, "a") as outfile: 
                outfile.write(line_to_write)

# %%
abstracts_classified_file = "/Users/lmoncla/src/h5n1-host-classification/abstracts/abstracts-classified-2020-09-28.txt"
strain_classification_file = "/Users/lmoncla/src/h5n1-host-classification/abstracts/strain_specific_annotations.txt"

# %%
classified_by_abstract_dict = read_in_classified_abstracts(abstracts_classified_file)
strains_abstract_dict = read_in_strain_specific_classifications_file(strain_classification_file)

# %%
metadata_directory = "/Users/lmoncla/src/h5n1-host-classification/metadata-with-annotations/"
todays_date = (datetime.datetime.now()).strftime('%Y-%m-%d')
genes_to_run = ['pb2','pb1','pa','ha','np','na','mp','ns']

for gene in genes_to_run: 
    metadata_file = metadata_directory + "metadata_h5n1_" + gene + "_with_accessions_2020-10-02.txt"
    output_filename = metadata_directory + "metadata_h5n1_" + gene + "_final_"+ todays_date+".txt"
    add_manual_annotations(metadata_file, classified_by_abstract_dict, strains_abstract_dict, output_filename)
